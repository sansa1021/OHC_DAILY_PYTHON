# %%
logs = ["hit:100", "miss:0", "hit:50", "hit:30"]
def damage(log_text):
    p = log_text.split(':')
    d = int(p[1]) #ㄴ여기서 처음에 p[0:7]로 입력했더니 에러남
    return d
result = list(map(damage, logs))
print(result)
# Out:
# [100, 0, 50, 30]
