# %%
#scores = {"산사": 90, "잼민이": 75, "영희": 85, "철수": 50}
#pairs = list(scores.items())
#def high(students):
    #ㄴ딱 여기까지 하고 막힌...
scores = {"산사": 90, "잼민이": 75, "영희": 85, "철수": 50}
pa_students = []
pairs = list(scores.items())
for name, score in scores.items():
    if score >= 80:
        pa_students.append(name)
print(pa_students)
#ㄴ딕셔너리->리스트 변환 방법과 append()함수를 까먹었엇다. 사실 다까먹은거나 다름없다...실망스럽다
# Out:
# ['산사', '영희']
